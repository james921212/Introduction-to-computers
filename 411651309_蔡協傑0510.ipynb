# %% [markdown]
# <a href="https://colab.research.google.com/github/james921212/Introduction-to-computers/blob/main/411651309_%E8%94%A1%E5%8D%94%E5%82%910510.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
password=int(input('請輸入密碼'))
if password==1234:
  print('歡迎光臨!')
# Out:
# 請輸入密碼69

# %%
password=int(input('請輸入密碼'))
if password==1234:
  print('密碼正確!')
else:
  print('密碼錯誤')
# Out:
# 請輸入密碼56
# 密碼錯誤

# %%
rain=input('今天會下雨嗎?(輸入y or Y)')
if(rain=='Y' or rain=="y"):
  if(rain=='Y'):
    print('不用帶傘')
  else:
    print('出門記得帶傘')
else:
  print('輸入錯誤')
# Out:
# 今天會下雨嗎?(輸入y or Y)y
# 出門記得帶傘

# %%
a=int(input('請輸入正整數'))
if a%2==0:
  print(a,'為偶數')
else:
  print(a,'為奇數')
# Out:
# 請輸入正整數34
# 34 為偶數
