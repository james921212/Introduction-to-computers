# %% [markdown]
# <a href="https://colab.research.google.com/github/james921212/Introduction-to-computers/blob/main/411651309_%E8%94%A1%E5%8D%94%E5%82%91_0503.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# print文字

# %%
a =input()
print(a)
# Out:
# Panda
# Panda

# %% [markdown]
# 取得字串長度

# %%
a=input()
print(len(a))
# Out:
# Good to drink ?
# 15

# %% [markdown]
# BMI計算

# %%
h,w= input().split()
new_h=int(h)/100
new_w=int(w)
bmi = new_w/new_h**2
print('%.2f' % bmi)
# Out:
# 173 70
# 23.39

# %% [markdown]
# 正整數

# %%
total=0
for i in range(10,51):
  total+=i
print(total)
# Out:
# 1230
