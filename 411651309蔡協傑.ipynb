# %% [markdown]
# <a href="https://colab.research.google.com/github/james921212/Introduction-to-computers/blob/main/411651309%E8%94%A1%E5%8D%94%E5%82%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age,name=18,"James"

# %%
age
# Out:
# 18

# %%
name
# Out:
# 'James'

# %%
str3="James說:'Hey,你好'"
str4='James說:"Hey,你好"'

# %%
str3
# Out:
# "James說:'Hey,你好'"

# %%
str4
# Out:
# 'James說:"Hey,你好"'

# %%
print(type(56))
print(type(56.0))
print(type("Hey,how are you?"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
