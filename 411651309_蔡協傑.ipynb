# %% [markdown]
# <a href="https://colab.research.google.com/github/james921212/Introduction-to-computers/blob/main/411651309_%E8%94%A1%E5%8D%94%E5%82%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello!')
print('你好!')
print('今天是3/1!')
print('411651309_蔡協傑')
# Out:
# Hello!
# 你好!
# 今天是3/1!
# 411651309_蔡協傑

# %%
a=2
b=3
c=7
a,b,c
# Out:
# (2, 3, 7)

# %%
d=25
e=57
f=35
d,e,f
# Out:
# (25, 57, 35)

# %%
a+b+c
# Out:
# 12

# %%
a+b+c+d+e+f
# Out:
# 129

# %%
g=a+b+c+d+e+f

# %%
g
# Out:
# 129

# %%
f-a
# Out:
# 33

# %%
f+b-d+e-b-c
# Out:
# 60

# %%
h=i=j=4
h,i,j
# Out:
# (4, 4, 4)
